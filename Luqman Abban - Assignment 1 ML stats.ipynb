# %% [markdown]
# # Assignment 1 ML Stats
# # Luqman Abban

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:/DS activities/ML/Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#removing duplicates and missing values
car = df.drop_duplicates()
car_sales= car.dropna()
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# 1. Identify the variable types in the given data set.

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %% [markdown]
# 2. Make a bar graph for manufacturer type

# %%
M_count= car_sales['Manufacturer'].value_counts()

plt.figure(figsize=(10,6))
plt.bar(M_count.index, M_count.values)
plt.title('Number of Vehicles by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3. Make a pie chart for showing vehicle type by percentage

# %%
V_type= car_sales['Vehicle_type'].value_counts()
plt.figure(figsize=(5,6))
plt.pie(V_type, labels=V_type.index, autopct='%1.1f%%', wedgeprops=dict(edgecolor='black', linewidth=1))
plt.title('Vehicle Distribution by Manufacturer')
plt.axis('equal') 
plt.show()

# %% [markdown]
# 4. Calculate average Price of all cars by using correct measure of central Tendency

# %%
car_sales.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          117.000000           117.000000          117.000000
# mean            59.112316            18.031538           25.969487
# std             75.058933            11.605632           14.149699
# min              0.110000             5.160000            9.235000
# 25%             16.767000            11.240000           16.980000
# 50%             32.299000            14.010000           21.665000
# 75%             76.029000            19.875000           29.465000
# max            540.561000            67.550000           82.600000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean      3.048718  181.282051  107.326496   71.189744  187.717949
# std       1.055169   58.591786    8.050588    3.530151   13.849926
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
round(car_sales['Price_in_thousands'].mean(),2)
# Out:
# 25.97

# %%
car_sales['Price_in_thousands'].median()
# Out:
# 21.665

# %%
car_sales['Price_in_thousands'].mode()
# Out:
# 0    12.64
# Name: Price_in_thousands, dtype: float64

# %% [markdown]
# 5. Calculate the variance and standard deviation for numerical columns.

# %%
variance=round(car_sales.select_dtypes(include='number').var()),2
st_deviation=round(car_sales.select_dtypes(include='number').std()),2
print("Variance:\n", variance)
print("\nStandard Deviation:\n", st_deviation)
# Out:
# Variance:
#  (Sales_in_thousands     5634.0
# __year_resale_value     135.0
# Price_in_thousands      200.0
# Engine_size               1.0
# Horsepower             3433.0
# Wheelbase                65.0
# Width                    12.0
# Length                  192.0
# Curb_weight               0.0
# Fuel_capacity            14.0
# Fuel_efficiency          19.0
# Power_perf_factor       664.0
# dtype: float64, 2)
#
# Standard Deviation:
#  (Sales_in_thousands     75.0
# __year_resale_value    12.0
# Price_in_thousands     14.0
# Engine_size             1.0
# Horsepower             59.0
# Wheelbase               8.0
# Width                   4.0
# Length                 14.0
# Curb_weight             1.0
# Fuel_capacity           4.0
# Fuel_efficiency         4.0
# Power_perf_factor      26.0
# dtype: float64, 2)

# %% [markdown]
# 6. For the same columns Calculate IQR and identify outliers in these columns

# %%
column_n = ['Sales_in_thousands','Price_in_thousands','Engine_size','Horsepower']
outliers = {}
for column in column_n:
    if column in car_sales.columns:
        Q1 = car_sales[column].quantile(0.25)
        Q3 = car_sales[column].quantile(0.75)

        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outlier_indices = car_sales[(car_sales[column] < lower_bound) | (car_sales[column] > upper_bound)].index
        outlier_values = car_sales.loc[outlier_indices, column]
        outliers[column] = outlier_values
        

for column, outlier_df in outliers.items():
    print(f"Outliers in {column}:\n{outlier_df}\n")
# Out:
# Outliers in Sales_in_thousands:
# 40     227.061
# 45     181.749
# 49     245.815
# 52     276.747
# 55     220.650
# 56     540.561
# 57     199.685
# 58     230.902
# 137    247.994
# Name: Sales_in_thousands, dtype: float64
#
# Outliers in Price_in_thousands:
# 6      62.000
# 39     69.725
# 73     54.005
# 93     49.900
# 94     69.700
# 95     82.600
# 125    71.020
# 126    74.970
# 144    51.728
# Name: Price_in_thousands, dtype: float64
#
# Outliers in Engine_size:
# 39    8.0
# Name: Engine_size, dtype: float64
#
# Outliers in Horsepower:
# 24    345.0
# 39    450.0
# Name: Horsepower, dtype: float64

# %% [markdown]
# 7. Make Histograms for all Numerical columns and identify the distribution of type by calculating skewnes.

# %%
import matplotlib.pyplot as plt

columns = ['Sales_in_thousands', 'Price_in_thousands', 'Engine_size', 'Horsepower']

for column in columns:
    if column in car_sales.columns:
        
        plt.figure(figsize=(7, 5))
        car_sales[column].hist(bins=8)
        plt.title(f'{column}')
        plt.ylabel('Frequency')

        plt.show()

        skewness = car_sales[column].skew()
        print(f'Skewness of {column}: {skewness}\n')
# Out:
# Skewness of Sales_in_thousands: 3.1699938005978314
# Skewness of Price_in_thousands: 1.9449098262709537
# Skewness of Engine_size: 1.122624919323603
# Skewness of Horsepower: 1.2168365420073122

# %% [markdown]
# All Histograms are skewed to the right (long right tail) with Sales_in_thousands most skewed.
